# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df1=pd.read_csv("../data/2023-03-08 Precios Casas RM.csv")

# %%
df1.head()
# Out:
#    Price_CLP  Price_UF  Price_USD             Comuna              Ubicacion  \
# 0  409285000     11500     509695       QuintaNormal        Hoevel4548y4558
# 1  105000000      2950     130760  PedroAguirreCerda               Rucalhue
# 2  128124000      3600     159557    EstaciónCentral     AvenidaLasParcelas
# 3   75000000      2107      93400             Colina     PasajeGonzaloRojas
# 4   53000000      1489      66002             Colina  HernánDíazArrieta2820
#
#    Dorms  Baths  Built Area  Total Area  Parking        id  \
# 0      7    4.0       384.0       732.0      3.0  11700213
# 1      2    1.0       112.0       145.0      1.0  10894299
# 2      3    1.0        59.0       243.0      2.0  10257635
# 3      3    1.0       103.0        73.0      1.0   9232092
# 4      2    1.0        57.0        67.0      1.0   7085397
#
#                         Realtor
# 0                           NaN
# 1     Legales y Propiedades SpA
# 2                 Propiedadesrs
# ...

# %%
df2=pd.read_csv("../data/2023-07-18 Propiedades Web Scrape.csv")

# %%
df2.head()
# Out:
#    Price_CLP  Price_UF  Price_USD        Comuna  \
# 0  129884400    3600.0   158396.0         Lampa
# 1  130000000    3603.0   158537.0          Buin
# 2  172998805    4795.0   210974.0    PuenteAlto
# 3  135296250    3750.0   164995.0          Buin
# 4  195000000    5405.0   237805.0  QuintaNormal
#
#                          Ubicacion  Dorms  Baths  Built Area  Total Area  \
# 0                AvenidaLaHacienda    3.0    2.0        68.0       221.0
# 1                        Villaseca    5.0    3.0       150.0       190.0
# 2                    BarrioAustria    4.0    3.0        90.0       182.0
# 3  ComercianteArmandoPérezCarrasco    3.0    2.0        85.0       175.0
# 4                           Hostos    3.0    3.0       130.0       402.0
#
#    Parking        id               Realtor
# 0      1.0   7850612               Behouse
# 1      2.0  10081485                   NaN
# 2      3.0  10257247                Bissac
# 3      1.0  20153043  Ambiento Propiedades
# ...

# %%
propiedades_df=pd.concat([df1,df2])

# %%
propiedades_df.shape
# Out:
# (17070, 12)

# %%
df1.shape
df2.shape
# Out:
# (9291, 12)

# %%
propiedades_df.head()
# Out:
#    Price_CLP  Price_UF  Price_USD             Comuna              Ubicacion  \
# 0  409285000   11500.0   509695.0       QuintaNormal        Hoevel4548y4558
# 1  105000000    2950.0   130760.0  PedroAguirreCerda               Rucalhue
# 2  128124000    3600.0   159557.0    EstaciónCentral     AvenidaLasParcelas
# 3   75000000    2107.0    93400.0             Colina     PasajeGonzaloRojas
# 4   53000000    1489.0    66002.0             Colina  HernánDíazArrieta2820
#
#    Dorms  Baths  Built Area  Total Area  Parking        id  \
# 0    7.0    4.0       384.0       732.0      3.0  11700213
# 1    2.0    1.0       112.0       145.0      1.0  10894299
# 2    3.0    1.0        59.0       243.0      2.0  10257635
# 3    3.0    1.0       103.0        73.0      1.0   9232092
# 4    2.0    1.0        57.0        67.0      1.0   7085397
#
#                         Realtor
# 0                           NaN
# 1     Legales y Propiedades SpA
# 2                 Propiedadesrs
# ...

# %%
propiedades_df.sort_values('id')
# Out:
#        Price_CLP  Price_UF  Price_USD       Comuna  \
# 4321  1582331400   44460.0  1970525.0  SanBernardo
# 4869  1604072340   44460.0  1956186.0  SanBernardo
# 3512   569440000   16000.0   709141.0      LaReina
# 2905   341308100    9590.0   425041.0        Ñuñoa
# 2745   889750000   25000.0  1108032.0     Vitacura
# ...          ...       ...        ...          ...
# 231    166000000    4601.0   202439.0    LaFlorida
# 230     59990000    1663.0    73159.0     Pudahuel
# 229     89990000    2494.0   109744.0        Maipú
# 228     53000000    1469.0    64634.0        Maipú
# 225    150000000    4158.0   182927.0        Maipú
#
#                          Ubicacion  Dorms  Baths  Built Area  Total Area  \
# 4321  Autopiatacentral/EstacionNos    3.0    2.0       200.0     12500.0
# 4869  Autopiatacentral/EstacionNos    3.0    2.0       200.0     12500.0
# 3512       Loreley/Monseñoredwards    4.0    3.0       180.0       600.0
# ...

# %%
print(propiedades_df.sort_values('id',ascending=True))
# Out:
#        Price_CLP  Price_UF  Price_USD       Comuna  \
# 4321  1582331400   44460.0  1970525.0  SanBernardo
# 4869  1604072340   44460.0  1956186.0  SanBernardo
# 3512   569440000   16000.0   709141.0      LaReina
# 2905   341308100    9590.0   425041.0        Ñuñoa
# 2745   889750000   25000.0  1108032.0     Vitacura
# ...          ...       ...        ...          ...
# 231    166000000    4601.0   202439.0    LaFlorida
# 230     59990000    1663.0    73159.0     Pudahuel
# 229     89990000    2494.0   109744.0        Maipú
# 228     53000000    1469.0    64634.0        Maipú
# 225    150000000    4158.0   182927.0        Maipú
#
#                          Ubicacion  Dorms  Baths  Built Area  Total Area  \
# 4321  Autopiatacentral/EstacionNos    3.0    2.0       200.0     12500.0
# 4869  Autopiatacentral/EstacionNos    3.0    2.0       200.0     12500.0
# 3512       Loreley/Monseñoredwards    4.0    3.0       180.0       600.0
# ...

# %%
propiedades_df=propiedades_df.dropna(subset=['id'])

# %%
propiedades_df.shape
# Out:
# (17070, 12)

# %%
propiedades_df.describe
# Out:
# <bound method NDFrame.describe of        Price_CLP  Price_UF  Price_USD             Comuna  \
# 0      409285000   11500.0   509695.0       QuintaNormal
# 1      105000000    2950.0   130760.0  PedroAguirreCerda
# 2      128124000    3600.0   159557.0    EstaciónCentral
# 3       75000000    2107.0    93400.0             Colina
# 4       53000000    1489.0    66002.0             Colina
# ...          ...       ...        ...                ...
# 9286    80000000    2217.0    97561.0         PuenteAlto
# 9287   250000000    6929.0   304878.0         PuenteAlto
# 9288  3788295000  105000.0  4619872.0          LasCondes
# 9289   577264000   16000.0   703980.0          LaPintana
# 9290   360717842    9998.0   439900.0          Talagante
#
#                              Ubicacion  Dorms  Baths  Built Area  Total Area  \
# 0                      Hoevel4548y4558    7.0    4.0       384.0       732.0
# 1                             Rucalhue    2.0    1.0       112.0       145.0
# ...

# %%
nulos=propiedades_df.isnull().sum()
print(nulos)
# Out:
# Price_CLP        0
# Price_UF         0
# Price_USD        0
# Comuna           0
# Ubicacion        0
# Dorms           77
# Baths          173
# Built Area       0
# Total Area      32
# Parking       5021
# id               0
# Realtor       1654
# dtype: int64

# %%
propiedades_df=propiedades_df.dropna(subset=['Built Area'])

# %%
print(nulos)
# Out:
# Price_CLP        0
# Price_UF         0
# Price_USD        0
# Comuna           0
# Ubicacion        0
# Dorms           77
# Baths          173
# Built Area       0
# Total Area      32
# Parking       5021
# id               0
# Realtor       1654
# dtype: int64

# %%
propiedades_sin_duplicados=propiedades_df.drop_duplicates(subset=['id'])
propiedades_sin_duplicados.shape
# Out:
# (13436, 12)

# %%
propiedades_sin_duplicados.to_csv('../data/df_propiedades.csv', index=False)
